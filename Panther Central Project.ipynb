# %% [markdown]
# ## CMPINF-0010-Final-Project
#
# Team Name: Panthers Central
#
# # **The Best Neighborhood Project**
#
# Our assignment was to discover which neighborhood in the city of Pittsburgh is the best.
#
# # **Metric**:
# We decided a god way to determine which neighborhood is the best is to discover which has residents less dependent upon living assistance provided by the city. We were initially going to use the amount household services and the number of arrests in each neighborhood and compare them, but decided to use the total number of fire incidents and crime arrests to be the deciding factor. We chose our metric to be that the higher amount of crimes committed (total amount of crimes and fire incidents) would result in a higher living assistance needed from the city in that neighborhood and vice versa. The best neighborhood would require the least amount of living assistance (least amount of arrests and fires).

# %% [markdown]
# # Test Number 1: Number of Arrests Made

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests.head(10)
# Out:
#         neighborhood  population  overall_crime_rate  number_arrests_murder  \
# 0          31st Ward        7594                2.03                      0
# 1   Allegheny Center         588               52.04                      0
# 2     Allegheny West        1159               14.33                      1
# 3          Allentown        5042                3.13                      0
# 4          Arlington        4758                2.50                      0
# 5  Arlington Heights        1989                6.19                      0
# 6         Banksville        6235                1.94                      0
# 7  Bedford Dwellings        3635                2.64                      1
# 8          Beechview       12965                1.98                      1
# 9        Beltzhoover        5980                6.37                      1
#
#    crime_rate_murder  number_arrests_rape  crime_rate_rape  \
# 0               0.00                    1             0.01
# 1               0.00                    2             0.34
# 2               0.09                    3             0.26
# 3               0.00                    1             0.08
# 4               0.00                    0             0.00
# 5               0.00                    2             0.10
# 6               0.00                    2             0.03
# 7               0.03                    4             0.11
# 8               0.01                    1             0.01
# 9               0.02                    3             0.05
#
#    number_arrests_robbery  crime_rate_robbery  number_arrests_assault  \
# 0                       7                0.09                      45
# 1                      24                4.08                      30
# 2                      16                1.38                      17
# 3                      23                0.46                      41
# 4                       7                0.15                      33
# 5                      14                0.70                      61
# 6                       8                0.13                       8
# 7                      11                0.30                      25
# 8                      26                0.20                      43
# 9                      63                1.05                      58
#
#    crime_rate_assault  number_arrests_burglary  crime_rate_burglary  \
# 0                0.60                       55                 0.73
# 1                5.10                       14                 2.38
# 2                1.47                       53                 4.57
# 3                0.81                       48                 0.95
# 4                0.69                       44                 0.92
# 5                3.07                       21                 1.06
# 6                0.13                       53                 0.85
# 7                0.69                       36                 0.99
# 8                0.33                       84                 0.65
# 9                0.97                      121                 2.02
#
#    number_arrests_larceny  crime_rate_larceny
# 0                      45                0.60
# 1                     236               40.14
# 2                      76                6.56
# 3                      45                0.89
# 4                      35                0.74
# 5                      25                1.26
# 6                      50                0.80
# 7                      19                0.52
# 8                     101                0.78
# 9                     135                2.26

# %% [markdown]
# First, we printed the first ten rows in this dataset to get an diea of how it was displayed.

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests[['neighborhood', 'number_arrests_murder','number_arrests_larceny','number_arrests_rape', 'number_arrests_robbery', 'number_arrests_assault','number_arrests_burglary' ]].head(30)
# Out:
#                             neighborhood  number_arrests_murder  \
# 0                              31st Ward                      0
# 1                       Allegheny Center                      0
# 2                         Allegheny West                      1
# 3                              Allentown                      0
# 4                              Arlington                      0
# 5                      Arlington Heights                      0
# 6                             Banksville                      0
# 7                      Bedford Dwellings                      1
# 8                              Beechview                      1
# 9                            Beltzhoover                      1
# 10                            Bloomfield                      0
# 11                               Bon Air                      0
# 12                      Brighton Heights                      0
# 13                             Brookline                      0
# 14                       California Ave.                      0
# 15                               Carrick                      1
# 16                    Central North Side                      1
# 17  Crafton Heights - Westwood - Oakwood                      1
# 18                         East Carnegie                      0
# 19                            East Hills                      2
# 20                          East Liberty                      1
# 21                       East North Side                      0
# 22                                Elliot                      0
# 23                                Esplen                      0
# 24                            Friendship                      0
# 25                              Garfield                      1
# 26                            Greenfield                      0
# 27                        Harpen Hilltop                      0
# 28         Hazelwood-Glenwood-Glen Hazel                      0
# 29                         Highland Park                      0
#
#     number_arrests_larceny  number_arrests_rape  number_arrests_robbery  \
# 0                       45                    1                       7
# 1                      236                    2                      24
# 2                       76                    3                      16
# 3                       45                    1                      23
# 4                       35                    0                       7
# 5                       25                    2                      14
# 6                       50                    2                       8
# 7                       19                    4                      11
# 8                      101                    1                      26
# 9                      135                    3                      63
# 10                     235                    5                      52
# 11                       9                    1                       1
# 12                      51                    2                       9
# 13                     119                    1                      22
# 14                      10                    2                       7
# 15                      92                    5                      19
# 16                     217                    4                     115
# 17                      42                    1                      10
# 18                       8                    0                       0
# 19                      37                    5                      16
# 20                     324                    5                      81
# 21                     125                    4                      57
# 22                      30                    0                       4
# 23                      18                    0                       1
# 24                      54                    2                       8
# 25                     142                    6                      48
# 26                      91                    3                      13
# 27                      12                    0                       2
# 28                     100                    1                      53
# 29                     196                    6                      18
#
#     number_arrests_assault  number_arrests_burglary
# 0                       45                       55
# 1                       30                       14
# 2                       17                       53
# 3                       41                       48
# 4                       33                       44
# 5                       61                       21
# 6                        8                       53
# 7                       25                       36
# 8                       43                       84
# 9                       58                      121
# 10                      77                      196
# 11                       8                       23
# 12                      40                       72
# 13                      56                      123
# 14                      14                       25
# 15                      68                      123
# 16                     208                      183
# 17                      22                       66
# 18                       3                        7
# 19                      30                       69
# 20                      81                      182
# 21                     102                       89
# 22                      29                       21
# 23                      12                       12
# 24                      16                       62
# 25                     100                      123
# 26                      36                      141
# 27                       3                        6
# 28                     125                       96
# 29                      45                      132

# %% [markdown]
# Then, we organized the table by removing the excess columns to only have the neighborhoods columns with each type crime people were arrested for.

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
print(pgh_arrests[['neighborhood','sum_of_arrests']].head(30))
pgh_arrests[['neighborhood','sum_of_arrests']].tail(40)
# Out:
#                             neighborhood  sum_of_arrests
# 0                              31st Ward             153
# 1                       Allegheny Center             306
# 2                         Allegheny West             166
# 3                              Allentown             158
# 4                              Arlington             119
# 5                      Arlington Heights             123
# 6                             Banksville             121
# 7                      Bedford Dwellings              96
# 8                              Beechview             256
# 9                            Beltzhoover             381
# 10                            Bloomfield             565
# 11                               Bon Air              42
# 12                      Brighton Heights             174
# 13                             Brookline             321
# 14                       California Ave.              58
# 15                               Carrick             308
# 16                    Central North Side             728
# 17  Crafton Heights - Westwood - Oakwood             142
# 18                         East Carnegie              18
# 19                            East Hills             159
# 20                          East Liberty             674
# 21                       East North Side             377
# 22                                Elliot              84
# 23                                Esplen              43
# 24                            Friendship             142
# 25                              Garfield             420
# 26                            Greenfield             284
# 27                        Harpen Hilltop              23
# 28         Hazelwood-Glenwood-Glen Hazel             375
# 29                         Highland Park             397
#                            neighborhood  sum_of_arrests
# 30                       Homewood North             276
# 31                       Homewood South             595
# 32                        Homewood West             179
# 33                            Knoxville             193
# 34                              Larimer             367
# 35                        Lawrenceville             320
# 36             Lincoln-Lemington-Belmar             277
# 37                  Lower Lawrenceville             316
# 38                        Lower Oakland             645
# 39                           Manchester             501
# 40                          Middle Hill             710
# 41                          Morningside              76
# 42  Mount Washington - Duquesne Heights             602
# 43                        North Oakland             926
# 44                   North View Heights             245
# 45                          Perry North             139
# 46                          Perry South             496
# 47                         Point Breeze             150
# 48                          Polish Hill              91
# 49                        Regent Square              55
# 50             Ridgemont - Chicken Hill             103
# 51                Shadeland Halls Grove             143
# 52                            Shadyside            1229
# 53                   Sheraton Chartiers             196
# 54                        South Oakland             257
# 55                      Southside Flats             518
# 56                     Southside Slopes             153
# 57                          Spring Hill             128
# 58      Squirrel Hill - North of Forbes             816
# 59      Squirrel Hill - South of Forbes            1066
# 60                            St. Clair             328
# 61                      Stanton Heights             163
# 62                            The Strip             302
# 63                       Swisshelm Park              35
# 64                      Terrace Village             544
# 65                            The Bluff             414
# 66                            Troy Hill              93
# 67                           Upper Hill             280
# 68                  Upper Lawrenceville             104
# 69                      West End Valley              46

# %% [markdown]
# Next, we added all the columns with each type of crime arrests (murder, rape, burglary, assault, robbery, and larceny) to get the sum for each neighborhood and created a new column in the dataset.

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
amount=pgh_arrests[['neighborhood','sum_of_arrests']].sort_values(by='sum_of_arrests', ascending=False)
print(amount.head(30))
amount.tail(40)
# Out:
#                            neighborhood  sum_of_arrests
# 52                            Shadyside            1229
# 59      Squirrel Hill - South of Forbes            1066
# 43                        North Oakland             926
# 58      Squirrel Hill - North of Forbes             816
# 16                   Central North Side             728
# 40                          Middle Hill             710
# 20                         East Liberty             674
# 38                        Lower Oakland             645
# 42  Mount Washington - Duquesne Heights             602
# 31                       Homewood South             595
# 10                           Bloomfield             565
# 64                      Terrace Village             544
# 55                      Southside Flats             518
# 39                           Manchester             501
# 46                          Perry South             496
# 25                             Garfield             420
# 65                            The Bluff             414
# 29                        Highland Park             397
# 9                           Beltzhoover             381
# 21                      East North Side             377
# 28        Hazelwood-Glenwood-Glen Hazel             375
# 34                              Larimer             367
# 60                            St. Clair             328
# 13                            Brookline             321
# 35                        Lawrenceville             320
# 37                  Lower Lawrenceville             316
# 15                              Carrick             308
# 1                      Allegheny Center             306
# 62                            The Strip             302
# 26                           Greenfield             284
#                             neighborhood  sum_of_arrests
# 67                            Upper Hill             280
# 36              Lincoln-Lemington-Belmar             277
# 30                        Homewood North             276
# 54                         South Oakland             257
# 8                              Beechview             256
# 44                    North View Heights             245
# 53                    Sheraton Chartiers             196
# 33                             Knoxville             193
# 32                         Homewood West             179
# 12                      Brighton Heights             174
# 2                         Allegheny West             166
# 61                       Stanton Heights             163
# 19                            East Hills             159
# 3                              Allentown             158
# 56                      Southside Slopes             153
# 0                              31st Ward             153
# 47                          Point Breeze             150
# 51                 Shadeland Halls Grove             143
# 24                            Friendship             142
# 17  Crafton Heights - Westwood - Oakwood             142
# 45                           Perry North             139
# 57                           Spring Hill             128
# 5                      Arlington Heights             123
# 6                             Banksville             121
# 4                              Arlington             119
# 68                   Upper Lawrenceville             104
# 50              Ridgemont - Chicken Hill             103
# 7                      Bedford Dwellings              96
# 66                             Troy Hill              93
# 48                           Polish Hill              91
# 22                                Elliot              84
# 41                           Morningside              76
# 14                       California Ave.              58
# 49                         Regent Square              55
# 69                       West End Valley              46
# 23                                Esplen              43
# 11                               Bon Air              42
# 63                        Swisshelm Park              35
# 27                        Harpen Hilltop              23
# 18                         East Carnegie              18

# %% [markdown]
# Finally, we organzied the data from highest crime arrest total to lowest for each neighborhood. The data shows that Shadyside has the highest and East Carnegie has the lowest.

# %% [markdown]
# We printed bar graph showing the sum of arrests for each neighborhood in Pittsburgh.

# %%
import matplotlib.pyplot as plt
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
neighborhoods=pgh_arrests['neighborhood']
pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
pgh_arrests_total=pgh_arrests[['neighborhood','sum_of_arrests']].plot.bar(figsize=(25,2),width=0.5, position=1)
plt.xticks(pgh_arrests.index,pgh_arrests['neighborhood'].values, fontsize=14)
plt.ylabel('Number of Crime Arrests')
# Out:
# Text(0,0.5,'Number of Crime Arrests')

# %% [markdown]
# # Test Number 2: Number of Fire Incidents

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires.head(10)
# Out:
#       call_no  incident_type                     type_description  \
# 0  F160029985          111.0                        Building fire
# 1  F180022058          111.0                        Building fire
# 2  F180022102          131.0               Passenger vehicle fire
# 3  F170043431          131.0               Passenger vehicle fire
# 4  F180021111          111.0                        Building fire
# 5  F180021782          150.0          Outside rubbish fire, Other
# 6  F180022495          113.0  Cooking fire, confined to container
# 7  F180022546          111.0                        Building fire
# 8  F180022773          111.0                        Building fire
# 9  F170044316          131.0               Passenger vehicle fire
#
#                                           address           alarm_time  \
# 0       800 BLOCK CENTER ST, WILKINSBURG PA 15221  2016-04-21T05:01:04
# 1        1100 BLOCK JANE ST, WILKINSBURG PA 15221  2018-03-13T08:34:43
# 2  SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212  2018-03-13T11:54:23
# 3      1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212  2017-05-31T08:39:47
# 4      2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205  2018-03-09T10:26:42
# 5     S 7TH ST & E CARSON ST, PITTSBURGH PA 15203  2018-03-12T09:13:28
# 6        200 BLOCK E OHIO ST, PITTSBURGH PA 15212  2018-03-14T19:46:10
# 7   7000 BLOCK LEMINGTON AVE, PITTSBURGH PA 15206  2018-03-14T23:49:22
# 8      100 BLOCK SPENCER AVE, PITTSBURGH PA 15227  2018-03-15T20:39:05
# 9    1200 BLOCK WESTFIELD ST, PITTSBURGH PA 15216  2017-06-03T01:31:13
#
#    alarms primary_unit  census_tract              neighborhood  \
# 0       1      231EN16           NaN                       NaN
# 1       1      231EN16           NaN                       NaN
# 2       0      231EN32        2406.0                       NaN
# 3       0      231EN38        2509.0                  Fineview
# 4       1      231EN31        2808.0                 Fairywood
# 5       0      231EN24        1702.0          South Side Flats
# 6       1      231EN32        2204.0          Allegheny Center
# 7       1      231EN15        1203.0  Lincoln-Lemington-Belmar
# 8       1      231EN23        2904.0                   Carrick
# 9       0      231EN28        1916.0                 Beechview
#
#    council_district  ward         tract  public_works_division  pli_division  \
# 0               NaN   NaN  4.200356e+10                    NaN           NaN
# 1               NaN   NaN  4.200356e+10                    NaN           NaN
# 2               NaN   NaN           NaN                    NaN           NaN
# 3               6.0  25.0  4.200325e+10                    1.0          25.0
# 4               2.0  28.0  4.200356e+10                    5.0          28.0
# 5               3.0  17.0  4.200317e+10                    4.0          17.0
# 6               1.0  22.0  4.200356e+10                    1.0          22.0
# 7               9.0  12.0  4.200312e+10                    2.0          12.0
# 8               4.0  29.0  4.200329e+10                    4.0          29.0
# 9               4.0  19.0  4.200319e+10                    5.0          19.0
#
#    police_zone fire_zone   latitude  longitude
# 0          NaN      3-16  40.441275 -79.882485
# 1          NaN      3-21  40.436342 -79.881003
# 2          NaN      1-1A        NaN        NaN
# 3          1.0      1-10  40.460303 -80.006980
# 4          6.0      1-16  40.449009 -80.076607
# 5          3.0       4-2  40.428618 -79.992239
# 6          1.0       1-6  40.453022 -80.003660
# 7          5.0      3-18  40.471358 -79.898240
# 8          3.0      4-15  40.385494 -79.977200
# 9          6.0      4-28  40.415219 -80.019516

# %% [markdown]
# First, we printed the first ten rows in this dataset.

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires[['neighborhood', 'type_description']]
# Out:
#                    neighborhood  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                      Fineview
# 4                     Fairywood
# 5              South Side Flats
# 6              Allegheny Center
# 7      Lincoln-Lemington-Belmar
# 8                       Carrick
# 9                     Beechview
# 10                    Allentown
# 11                  Beltzhoover
# 12                          NaN
# 13              Crafton Heights
# 14               Homewood North
# 15          Squirrel Hill South
# 16                  Perry North
# 17                    Allentown
# 18                          NaN
# 19            Bedford Dwellings
# 20               Homewood South
# 21               East Allegheny
# 22               Homewood North
# 23          Squirrel Hill South
# 24                  Beltzhoover
# 25             Crawford-Roberts
# 26                     Sheraden
# 27               Homewood South
# 28                  Middle Hill
# 29             South Side Flats
# ...                         ...
# 6566                  Brookline
# 6567         Point Breeze North
# 6568               East Liberty
# 6569               East Liberty
# 6570        Squirrel Hill North
# 6571  Central Business District
# 6572                        NaN
# 6573                        NaN
# 6574                South Shore
# 6575   Lincoln-Lemington-Belmar
# 6576                        NaN
# 6577                        NaN
# 6578  Central Business District
# 6579                  Overbrook
# 6580                        NaN
# 6581            Central Oakland
# 6582                        NaN
# 6583          Central Northside
# 6584             Homewood North
# 6585                        NaN
# 6586                 East Hills
# 6587                  Beechview
# 6588                        NaN
# 6589                    Carrick
# 6590               East Liberty
# 6591             East Allegheny
# 6592                  Knoxville
# 6593                  Shadyside
# 6594                        NaN
# 6595                        NaN
#
#                                      type_description
# 0                                       Building fire
# 1                                       Building fire
# 2                              Passenger vehicle fire
# 3                              Passenger vehicle fire
# 4                                       Building fire
# 5                         Outside rubbish fire, Other
# 6                 Cooking fire, confined to container
# 7                                       Building fire
# 8                                       Building fire
# 9                              Passenger vehicle fire
# 10               Outside rubbish, trash or waste fire
# 11                   Trash or rubbish fire, contained
# 12                Cooking fire, confined to container
# 13                                      Building fire
# 14              Brush or brush-and-grass mixture fire
# 15                        Special outside fire, Other
# 16                                      Building fire
# 17               Outside rubbish, trash or waste fire
# 18                             Passenger vehicle fire
# 19                                      Building fire
# 20              Mobile property (vehicle) fire, Other
# 21                                      Building fire
# 22                                      Building fire
# 23                Cooking fire, confined to container
# 24                                      Building fire
# 25                                      Building fire
# 26               Outside rubbish, trash or waste fire
# 27                Cooking fire, confined to container
# 28                                      Building fire
# 29                        Outside rubbish fire, Other
# ...                                               ...
# 6566                                    Building fire
# 6567              Cooking fire, confined to container
# 6568              Cooking fire, confined to container
# 6569                                    Building fire
# 6570                           Passenger vehicle fire
# 6571                 Trash or rubbish fire, contained
# 6572                                    Building fire
# 6573                           Passenger vehicle fire
# 6574              Cooking fire, confined to container
# 6575                           Passenger vehicle fire
# 6576                                    Building fire
# 6577             Outside rubbish, trash or waste fire
# 6578                                      Fire, Other
# 6579             Outside rubbish, trash or waste fire
# 6580                                    Building fire
# 6581              Cooking fire, confined to container
# 6582  Dumpster or other outside trash receptacle fire
# 6583                                    Building fire
# 6584                      Outside rubbish fire, Other
# 6585              Cooking fire, confined to container
# 6586              Cooking fire, confined to container
# 6587              Cooking fire, confined to container
# 6588                      Outside rubbish fire, Other
# 6589                                    Building fire
# 6590              Cooking fire, confined to container
# 6591             Outside rubbish, trash or waste fire
# 6592                           Passenger vehicle fire
# 6593  Dumpster or other outside trash receptacle fire
# 6594             Outside rubbish, trash or waste fire
# 6595                                    Building fire
#
# [6596 rows x 2 columns]

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
total_fires=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).value_counts()
print(total_fires)
# Out:
# neighborhood      type_description
# Allegheny Center  Cooking fire, confined to container                15
#                   Outside rubbish, trash or waste fire                6
#                   Dumpster or other outside trash receptacle fire     5
#                   Natural vegetation fire, Other                      5
#                   Brush or brush-and-grass mixture fire               3
#                   Building fire                                       2
#                   Special outside fire, Other                         2
#                   Trash or rubbish fire, contained                    2
#                   Fire in portable building, fixed location           1
#                   Fuel burner/boiler malfunction, fire confined       1
#                   Mobile property (vehicle) fire, Other               1
#                   Outside equipment fire                              1
#                   Outside rubbish fire, Other                         1
#                   Passenger vehicle fire                              1
# Allegheny West    Passenger vehicle fire                              8
#                   Building fire                                       5
#                   Dumpster or other outside trash receptacle fire     5
#                   Brush or brush-and-grass mixture fire               3
#                   Outside rubbish, trash or waste fire                3
#                   Commercial Compactor fire, confined to rubbish      2
#                   Natural vegetation fire, Other                      2
#                   Outside rubbish fire, Other                         2
#                   Cooking fire, confined to container                 1
#                   Grass fire                                          1
# Allentown         Building fire                                      34
#                   Cooking fire, confined to container                16
#                   Passenger vehicle fire                             10
#                   Outside rubbish, trash or waste fire                8
#                   Outside rubbish fire, Other                         6
#                   Dumpster or other outside trash receptacle fire     3
#                                                                      ..
# West Oakland      Commercial Compactor fire, confined to rubbish      2
#                   Dumpster or other outside trash receptacle fire     2
#                   Mobile property (vehicle) fire, Other               2
#                   Natural vegetation fire, Other                      2
#                   Outside rubbish, trash or waste fire                2
#                   Fire, Other                                         1
#                   Grass fire                                          1
# Westwood          Building fire                                       4
#                   Cooking fire, confined to container                 3
#                   Passenger vehicle fire                              3
#                   Brush or brush-and-grass mixture fire               2
#                   Dumpster or other outside trash receptacle fire     2
#                   Grass fire                                          2
#                   Fire, Other                                         1
#                   Natural vegetation fire, Other                      1
#                   Outside rubbish fire, Other                         1
#                   Outside rubbish, trash or waste fire                1
#                   Trash or rubbish fire, contained                    1
# Windgap           Brush or brush-and-grass mixture fire               2
#                   Building fire                                       2
#                   Cooking fire, confined to container                 2
#                   Outside rubbish fire, Other                         2
#                   Fire in mobile home used as fixed residence         1
#                   Forest, woods or wildland fire                      1
#                   Garbage dump or sanitary landfill fire              1
#                   Mobile property (vehicle) fire, Other               1
#                   Natural vegetation fire, Other                      1
#                   Outside rubbish, trash or waste fire                1
#                   Special outside fire, Other                         1
#                   Trash or rubbish fire, contained                    1
# Name: type_description, Length: 1158, dtype: int64

# %% [markdown]
# In this data table, we grouped each fire incident type reported with the corresponding neighborhood and counted each fire incident type listed. I used the the .nunique() method to get the number of different fire incidents reported in a neighborhood.

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
print(pgh_fires_sum)
# Out:
# neighborhood
# Allegheny Center              46
# Allegheny West                32
# Allentown                     89
# Arlington                     39
# Arlington Heights              9
# Banksville                    49
# Bedford Dwellings             31
# Beechview                    102
# Beltzhoover                   97
# Bloomfield                   120
# Bluff                         87
# Bon Air                       16
# Brighton Heights             105
# Brookline                    127
# California-Kirkbride          31
# Carrick                      221
# Central Business District    186
# Central Lawrenceville         58
# Central Northside             95
# Central Oakland               69
# Chartiers City                11
# Chateau                       34
# Crafton Heights               66
# Crawford-Roberts              77
# Duquesne Heights              23
# East Allegheny                78
# East Carnegie                  6
# East Hills                   122
# East Liberty                 149
# Elliott                       46
#                             ...
# Perry North                   83
# Perry South                  128
# Point Breeze                  57
# Point Breeze North            35
# Polish Hill                   24
# Regent Square                  6
# Ridgemont                     12
# Shadyside                    126
# Sheraden                     135
# South Oakland                 67
# South Shore                   18
# South Side Flats             184
# South Side Slopes             71
# Spring Garden                 19
# Spring Hill-City View         80
# Squirrel Hill North           96
# Squirrel Hill South          178
# St. Clair                     11
# Stanton Heights               43
# Strip District                35
# Summer Hill                   16
# Swisshelm Park                11
# Terrace Village               70
# Troy Hill                     54
# Upper Hill                    34
# Upper Lawrenceville           35
# West End                      16
# West Oakland                  46
# Westwood                      21
# Windgap                       16
# Name: type_description, Length: 91, dtype: int64

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
print(pgh_fires_sum.sort_values(ascending=False))
# Out:
# neighborhood
# Carrick                      221
# Central Business District    186
# South Side Flats             184
# Hazelwood                    183
# Squirrel Hill South          178
# East Liberty                 149
# Homewood North               146
# Lincoln-Lemington-Belmar     146
# Mount Washington             145
# Sheraden                     135
# Perry South                  128
# Homewood South               128
# Brookline                    127
# Shadyside                    126
# East Hills                   122
# Bloomfield                   120
# Knoxville                    117
# Brighton Heights             105
# Larimer                      102
# Beechview                    102
# Beltzhoover                   97
# Marshall-Shadeland            97
# Squirrel Hill North           96
# Central Northside             95
# North Oakland                 92
# Allentown                     89
# Bluff                         87
# Perry North                   83
# Greenfield                    82
# Spring Hill-City View         80
#                             ...
# Chateau                       34
# Allegheny West                32
# Bedford Dwellings             31
# California-Kirkbride          31
# Morningside                   26
# Friendship                    25
# Polish Hill                   24
# Duquesne Heights              23
# Westwood                      21
# New Homestead                 20
# Spring Garden                 19
# Fairywood                     18
# South Shore                   18
# Glen Hazel                    17
# West End                      16
# Summer Hill                   16
# Bon Air                       16
# Windgap                       16
# Esplen                        15
# Ridgemont                     12
# St. Clair                     11
# Swisshelm Park                11
# Chartiers City                11
# Hays                          11
# Oakwood                       10
# Arlington Heights              9
# Mt. Oliver                     7
# East Carnegie                  6
# Regent Square                  6
# Mount Oliver Borough           4
# Name: type_description, Length: 91, dtype: int64

# %% [markdown]
# This data now in order of highest fire incidents reported to lowest reveals that the neighborhood Carrick had the highest and Mount Oliver Borough had the lowest fire incidents reported.

# %%
import matplotlib.pyplot as plt
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
plt.ylabel('Number of fire incidents')
print(pgh_fires_sum.plot.bar(figsize=(25,2), width=0.5, position=1, fontsize=14))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Bar Graph displaying the different number of fire incidents reported in each Pittsburgh neighborhood.

# %% [markdown]
# # Comparing the Two Datasets

# %% [markdown]
# Now let's make a datatable with both the total numer of arrests for crimes and fire incidents reported aligned with each neighborhood.

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
pgh_arrests_total=pgh_arrests[['sum_of_arrests', 'neighborhood']]
pgh_total=pd.merge(pgh_arrests['sum_of_arrests'].to_frame(),pgh_fires_sum.to_frame(),left_on=None, right_on=None,left_index=False, right_index=False, on=pgh_arrests['neighborhood'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-e1f8d201cc33> in <module>()
#       5 pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
#       6 pgh_arrests_total=pgh_arrests[['sum_of_arrests', 'neighborhood']]
# ----> 7 pgh_total=pd.merge(pgh_arrests['sum_of_arrests'].to_frame(),pgh_fires_sum.to_frame(),left_on=None, right_on=None,left_index=False, right_index=False, on=pgh_arrests['neighborhood'])
#
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     549         (self.left_join_keys,
#     550          self.right_join_keys,
# --> 551          self.join_names) = self._get_merge_keys()
#     552
#     553         # validate the merge keys dtypes. We may need to coerce
#
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     844                             right_keys.append(
#     845                                 right._get_label_or_level_values(
# --> 846                                     rk, stacklevel=stacklevel))
#     847                             join_names.append(rk)
#     848                         else:
#
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 0                                31st Ward
# 1                         Allegheny Center
# 2                           Allegheny West
# 3                                Allentown
# 4                                Arlington
# 5                        Arlington Heights
# 6                               Banksville
# 7                        Bedford Dwellings
# 8                                Beechview
# 9                              Beltzhoover
# 10                              Bloomfield
# 11                                 Bon Air
# 12                        Brighton Heights
# 13                               Brookline
# 14                         California Ave.
# 15                                 Carrick
# 16                      Central North Side
# 17    Crafton Heights - Westwood - Oakwood
# 18                           East Carnegie
# 19                              East Hills
# 20                            East Liberty
# 21                         East North Side
# 22                                  Elliot
# 23                                  Esplen
# 24                              Friendship
# 25                                Garfield
# 26                              Greenfield
# 27                          Harpen Hilltop
# 28           Hazelwood-Glenwood-Glen Hazel
# 29                           Highland Park
#                       ...
# 40                             Middle Hill
# 41                             Morningside
# 42     Mount Washington - Duquesne Heights
# 43                           North Oakland
# 44                      North View Heights
# 45                             Perry North
# 46                             Perry South
# 47                            Point Breeze
# 48                             Polish Hill
# 49                           Regent Square
# 50                Ridgemont - Chicken Hill
# 51                   Shadeland Halls Grove
# 52                               Shadyside
# 53                      Sheraton Chartiers
# 54                           South Oakland
# 55                         Southside Flats
# 56                        Southside Slopes
# 57                             Spring Hill
# 58         Squirrel Hill - North of Forbes
# 59         Squirrel Hill - South of Forbes
# 60                               St. Clair
# 61                         Stanton Heights
# 62                               The Strip
# 63                          Swisshelm Park
# 64                         Terrace Village
# 65                               The Bluff
# 66                               Troy Hill
# 67                              Upper Hill
# 68                     Upper Lawrenceville
# 69                         West End Valley
# Name: neighborhood, Length: 70, dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
#print(pgh_fires_sum.plot.bar(figsize=(25,2), width=0.5, position=1, fontsize=14))
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
neighborhoods=pgh_arrests['neighborhood']
pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
#pgh_arrests_total=pgh_arrests[['neighborhood','sum_of_arrests']].plot.bar(figsize=(25,2),width=0.5, position=1)
plt.xticks(pgh_arrests.index,pgh_arrests['neighborhood'].values, fontsize=14)

# %% [markdown]
# # *The Best Neighborhood*
# Based on the results from our data, we can conclude that...
