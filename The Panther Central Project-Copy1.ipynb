# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests.head(10)
# Out:
#         neighborhood  population  overall_crime_rate  number_arrests_murder  \
# 0          31st Ward        7594                2.03                      0
# 1   Allegheny Center         588               52.04                      0
# 2     Allegheny West        1159               14.33                      1
# 3          Allentown        5042                3.13                      0
# 4          Arlington        4758                2.50                      0
# 5  Arlington Heights        1989                6.19                      0
# 6         Banksville        6235                1.94                      0
# 7  Bedford Dwellings        3635                2.64                      1
# 8          Beechview       12965                1.98                      1
# 9        Beltzhoover        5980                6.37                      1
#
#    crime_rate_murder  number_arrests_rape  crime_rate_rape  \
# 0               0.00                    1             0.01
# 1               0.00                    2             0.34
# 2               0.09                    3             0.26
# 3               0.00                    1             0.08
# 4               0.00                    0             0.00
# 5               0.00                    2             0.10
# 6               0.00                    2             0.03
# 7               0.03                    4             0.11
# 8               0.01                    1             0.01
# 9               0.02                    3             0.05
#
#    number_arrests_robbery  crime_rate_robbery  number_arrests_assault  \
# 0                       7                0.09                      45
# 1                      24                4.08                      30
# 2                      16                1.38                      17
# 3                      23                0.46                      41
# 4                       7                0.15                      33
# 5                      14                0.70                      61
# 6                       8                0.13                       8
# 7                      11                0.30                      25
# 8                      26                0.20                      43
# 9                      63                1.05                      58
#
#    crime_rate_assault  number_arrests_burglary  crime_rate_burglary  \
# 0                0.60                       55                 0.73
# 1                5.10                       14                 2.38
# 2                1.47                       53                 4.57
# 3                0.81                       48                 0.95
# 4                0.69                       44                 0.92
# 5                3.07                       21                 1.06
# 6                0.13                       53                 0.85
# 7                0.69                       36                 0.99
# 8                0.33                       84                 0.65
# 9                0.97                      121                 2.02
#
#    number_arrests_larceny  crime_rate_larceny
# 0                      45                0.60
# 1                     236               40.14
# 2                      76                6.56
# 3                      45                0.89
# 4                      35                0.74
# 5                      25                1.26
# 6                      50                0.80
# 7                      19                0.52
# 8                     101                0.78
# 9                     135                2.26

# %% [markdown]
# First, we printed the first ten rows in this dataset to get an idea of how it was displayed. This allowed us to see that there were several unwanted colomns describing the rate at which incidents happen rather than the quantity of incidents happening.

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests[['neighborhood', 'number_arrests_murder','number_arrests_larceny','number_arrests_rape', 'number_arrests_robbery', 'number_arrests_assault','number_arrests_burglary' ]].head(30)
# Out:
#                             neighborhood  number_arrests_murder  \
# 0                              31st Ward                      0
# 1                       Allegheny Center                      0
# 2                         Allegheny West                      1
# 3                              Allentown                      0
# 4                              Arlington                      0
# 5                      Arlington Heights                      0
# 6                             Banksville                      0
# 7                      Bedford Dwellings                      1
# 8                              Beechview                      1
# 9                            Beltzhoover                      1
# 10                            Bloomfield                      0
# 11                               Bon Air                      0
# 12                      Brighton Heights                      0
# 13                             Brookline                      0
# 14                       California Ave.                      0
# 15                               Carrick                      1
# 16                    Central North Side                      1
# 17  Crafton Heights - Westwood - Oakwood                      1
# 18                         East Carnegie                      0
# 19                            East Hills                      2
# 20                          East Liberty                      1
# 21                       East North Side                      0
# 22                                Elliot                      0
# 23                                Esplen                      0
# 24                            Friendship                      0
# 25                              Garfield                      1
# 26                            Greenfield                      0
# 27                        Harpen Hilltop                      0
# 28         Hazelwood-Glenwood-Glen Hazel                      0
# 29                         Highland Park                      0
#
#     number_arrests_larceny  number_arrests_rape  number_arrests_robbery  \
# 0                       45                    1                       7
# 1                      236                    2                      24
# 2                       76                    3                      16
# 3                       45                    1                      23
# 4                       35                    0                       7
# 5                       25                    2                      14
# 6                       50                    2                       8
# 7                       19                    4                      11
# 8                      101                    1                      26
# 9                      135                    3                      63
# 10                     235                    5                      52
# 11                       9                    1                       1
# 12                      51                    2                       9
# 13                     119                    1                      22
# 14                      10                    2                       7
# 15                      92                    5                      19
# 16                     217                    4                     115
# 17                      42                    1                      10
# 18                       8                    0                       0
# 19                      37                    5                      16
# 20                     324                    5                      81
# 21                     125                    4                      57
# 22                      30                    0                       4
# 23                      18                    0                       1
# 24                      54                    2                       8
# 25                     142                    6                      48
# 26                      91                    3                      13
# 27                      12                    0                       2
# 28                     100                    1                      53
# 29                     196                    6                      18
#
#     number_arrests_assault  number_arrests_burglary
# 0                       45                       55
# 1                       30                       14
# 2                       17                       53
# 3                       41                       48
# 4                       33                       44
# 5                       61                       21
# 6                        8                       53
# 7                       25                       36
# 8                       43                       84
# 9                       58                      121
# 10                      77                      196
# 11                       8                       23
# 12                      40                       72
# 13                      56                      123
# 14                      14                       25
# 15                      68                      123
# 16                     208                      183
# 17                      22                       66
# 18                       3                        7
# 19                      30                       69
# 20                      81                      182
# 21                     102                       89
# 22                      29                       21
# 23                      12                       12
# 24                      16                       62
# 25                     100                      123
# 26                      36                      141
# 27                       3                        6
# 28                     125                       96
# 29                      45                      132

# %% [markdown]
# To solve this problem we organized the table by removing the excess columns. Only the columns with the quantities of each type of incident were left. Now we have a dataset we can work with!

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests['sum_of_reports']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
print(pgh_arrests[['neighborhood','sum_of_reports']].head(30))
pgh_arrests[['neighborhood','sum_of_reports']].tail(40)
# Out:
#                             neighborhood  sum_of_reports
# 0                              31st Ward             153
# 1                       Allegheny Center             306
# 2                         Allegheny West             166
# 3                              Allentown             158
# 4                              Arlington             119
# 5                      Arlington Heights             123
# 6                             Banksville             121
# 7                      Bedford Dwellings              96
# 8                              Beechview             256
# 9                            Beltzhoover             381
# 10                            Bloomfield             565
# 11                               Bon Air              42
# 12                      Brighton Heights             174
# 13                             Brookline             321
# 14                       California Ave.              58
# 15                               Carrick             308
# 16                    Central North Side             728
# 17  Crafton Heights - Westwood - Oakwood             142
# 18                         East Carnegie              18
# 19                            East Hills             159
# 20                          East Liberty             674
# 21                       East North Side             377
# 22                                Elliot              84
# 23                                Esplen              43
# 24                            Friendship             142
# 25                              Garfield             420
# 26                            Greenfield             284
# 27                        Harpen Hilltop              23
# 28         Hazelwood-Glenwood-Glen Hazel             375
# 29                         Highland Park             397
#                            neighborhood  sum_of_reports
# 30                       Homewood North             276
# 31                       Homewood South             595
# 32                        Homewood West             179
# 33                            Knoxville             193
# 34                              Larimer             367
# 35                        Lawrenceville             320
# 36             Lincoln-Lemington-Belmar             277
# 37                  Lower Lawrenceville             316
# 38                        Lower Oakland             645
# 39                           Manchester             501
# 40                          Middle Hill             710
# 41                          Morningside              76
# 42  Mount Washington - Duquesne Heights             602
# 43                        North Oakland             926
# 44                   North View Heights             245
# 45                          Perry North             139
# 46                          Perry South             496
# 47                         Point Breeze             150
# 48                          Polish Hill              91
# 49                        Regent Square              55
# 50             Ridgemont - Chicken Hill             103
# 51                Shadeland Halls Grove             143
# 52                            Shadyside            1229
# 53                   Sheraton Chartiers             196
# 54                        South Oakland             257
# 55                      Southside Flats             518
# 56                     Southside Slopes             153
# 57                          Spring Hill             128
# 58      Squirrel Hill - North of Forbes             816
# 59      Squirrel Hill - South of Forbes            1066
# 60                            St. Clair             328
# 61                      Stanton Heights             163
# 62                            The Strip             302
# 63                       Swisshelm Park              35
# 64                      Terrace Village             544
# 65                            The Bluff             414
# 66                            Troy Hill              93
# 67                           Upper Hill             280
# 68                  Upper Lawrenceville             104
# 69                      West End Valley              46

# %% [markdown]
# Next, we added all the columns with each type of incident (murder, rape, burglary, assault, robbery, and larceny) to get the sum for each neighborhood and created a new column in the dataset called sum_of_arrests. Now we just need to organize.

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests['sum_of_reports']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
amount=pgh_arrests[['neighborhood','sum_of_reports']].sort_values(by='sum_of_reports', ascending=False)
print(amount.head(30))
print(amount.tail(40))
# Out:
#                            neighborhood  sum_of_reports
# 52                            Shadyside            1229
# 59      Squirrel Hill - South of Forbes            1066
# 43                        North Oakland             926
# 58      Squirrel Hill - North of Forbes             816
# 16                   Central North Side             728
# 40                          Middle Hill             710
# 20                         East Liberty             674
# 38                        Lower Oakland             645
# 42  Mount Washington - Duquesne Heights             602
# 31                       Homewood South             595
# 10                           Bloomfield             565
# 64                      Terrace Village             544
# 55                      Southside Flats             518
# 39                           Manchester             501
# 46                          Perry South             496
# 25                             Garfield             420
# 65                            The Bluff             414
# 29                        Highland Park             397
# 9                           Beltzhoover             381
# 21                      East North Side             377
# 28        Hazelwood-Glenwood-Glen Hazel             375
# 34                              Larimer             367
# 60                            St. Clair             328
# 13                            Brookline             321
# 35                        Lawrenceville             320
# 37                  Lower Lawrenceville             316
# 15                              Carrick             308
# 1                      Allegheny Center             306
# 62                            The Strip             302
# 26                           Greenfield             284
#                             neighborhood  sum_of_reports
# 67                            Upper Hill             280
# 36              Lincoln-Lemington-Belmar             277
# 30                        Homewood North             276
# 54                         South Oakland             257
# 8                              Beechview             256
# 44                    North View Heights             245
# 53                    Sheraton Chartiers             196
# 33                             Knoxville             193
# 32                         Homewood West             179
# 12                      Brighton Heights             174
# 2                         Allegheny West             166
# 61                       Stanton Heights             163
# 19                            East Hills             159
# 3                              Allentown             158
# 56                      Southside Slopes             153
# 0                              31st Ward             153
# 47                          Point Breeze             150
# 51                 Shadeland Halls Grove             143
# 24                            Friendship             142
# 17  Crafton Heights - Westwood - Oakwood             142
# 45                           Perry North             139
# 57                           Spring Hill             128
# 5                      Arlington Heights             123
# 6                             Banksville             121
# 4                              Arlington             119
# 68                   Upper Lawrenceville             104
# 50              Ridgemont - Chicken Hill             103
# 7                      Bedford Dwellings              96
# 66                             Troy Hill              93
# 48                           Polish Hill              91
# 22                                Elliot              84
# 41                           Morningside              76
# 14                       California Ave.              58
# 49                         Regent Square              55
# 69                       West End Valley              46
# 23                                Esplen              43
# 11                               Bon Air              42
# 63                        Swisshelm Park              35
# 27                        Harpen Hilltop              23
# 18                         East Carnegie              18

# %% [markdown]
# We listed the data from highest incident total to lowest incident total for each neighborhood using the .sort_values() method. The data shows that Shadyside has the highest total with 1226 whereas East Carnegie has the lowest at only 18. Now we can get a better visual of the graph.

# %% [markdown]
# We printed bar graph showing the sum of arrests for each neighborhood in Pittsburgh.

# %%
import matplotlib.pyplot as plt
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
neighborhoods=pgh_arrests['neighborhood']
pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
pgh_arrests_total=pgh_arrests[['neighborhood','sum_of_arrests']].plot.bar(figsize=(25,2),width=0.5, position=1)
plt.xticks(pgh_arrests.index,pgh_arrests['neighborhood'].values, fontsize=14)
plt.ylabel('Number of Incident Reports')
print(pgh_arrests_total)
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# # Test Number 2: Number of Fire Incidents

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires.head(10)
# Out:
#       call_no  incident_type                     type_description  \
# 0  F160029985          111.0                        Building fire
# 1  F180022058          111.0                        Building fire
# 2  F180022102          131.0               Passenger vehicle fire
# 3  F170043431          131.0               Passenger vehicle fire
# 4  F180021111          111.0                        Building fire
# 5  F180021782          150.0          Outside rubbish fire, Other
# 6  F180022495          113.0  Cooking fire, confined to container
# 7  F180022546          111.0                        Building fire
# 8  F180022773          111.0                        Building fire
# 9  F170044316          131.0               Passenger vehicle fire
#
#                                           address           alarm_time  \
# 0       800 BLOCK CENTER ST, WILKINSBURG PA 15221  2016-04-21T05:01:04
# 1        1100 BLOCK JANE ST, WILKINSBURG PA 15221  2018-03-13T08:34:43
# 2  SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212  2018-03-13T11:54:23
# 3      1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212  2017-05-31T08:39:47
# 4      2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205  2018-03-09T10:26:42
# 5     S 7TH ST & E CARSON ST, PITTSBURGH PA 15203  2018-03-12T09:13:28
# 6        200 BLOCK E OHIO ST, PITTSBURGH PA 15212  2018-03-14T19:46:10
# 7   7000 BLOCK LEMINGTON AVE, PITTSBURGH PA 15206  2018-03-14T23:49:22
# 8      100 BLOCK SPENCER AVE, PITTSBURGH PA 15227  2018-03-15T20:39:05
# 9    1200 BLOCK WESTFIELD ST, PITTSBURGH PA 15216  2017-06-03T01:31:13
#
#    alarms primary_unit  census_tract              neighborhood  \
# 0       1      231EN16           NaN                       NaN
# 1       1      231EN16           NaN                       NaN
# 2       0      231EN32        2406.0                       NaN
# 3       0      231EN38        2509.0                  Fineview
# 4       1      231EN31        2808.0                 Fairywood
# 5       0      231EN24        1702.0          South Side Flats
# 6       1      231EN32        2204.0          Allegheny Center
# 7       1      231EN15        1203.0  Lincoln-Lemington-Belmar
# 8       1      231EN23        2904.0                   Carrick
# 9       0      231EN28        1916.0                 Beechview
#
#    council_district  ward         tract  public_works_division  pli_division  \
# 0               NaN   NaN  4.200356e+10                    NaN           NaN
# 1               NaN   NaN  4.200356e+10                    NaN           NaN
# 2               NaN   NaN           NaN                    NaN           NaN
# 3               6.0  25.0  4.200325e+10                    1.0          25.0
# 4               2.0  28.0  4.200356e+10                    5.0          28.0
# 5               3.0  17.0  4.200317e+10                    4.0          17.0
# 6               1.0  22.0  4.200356e+10                    1.0          22.0
# 7               9.0  12.0  4.200312e+10                    2.0          12.0
# 8               4.0  29.0  4.200329e+10                    4.0          29.0
# 9               4.0  19.0  4.200319e+10                    5.0          19.0
#
#    police_zone fire_zone   latitude  longitude
# 0          NaN      3-16  40.441275 -79.882485
# 1          NaN      3-21  40.436342 -79.881003
# 2          NaN      1-1A        NaN        NaN
# 3          1.0      1-10  40.460303 -80.006980
# 4          6.0      1-16  40.449009 -80.076607
# 5          3.0       4-2  40.428618 -79.992239
# 6          1.0       1-6  40.453022 -80.003660
# 7          5.0      3-18  40.471358 -79.898240
# 8          3.0      4-15  40.385494 -79.977200
# 9          6.0      4-28  40.415219 -80.019516

# %% [markdown]
# First, we printed the first ten rows in this dataset to look at what was stored in it. This dataset has the same problem of unwanted colomn categories.

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires[['neighborhood', 'type_description']]
# Out:
#                    neighborhood                       type_description
# 0                           NaN                          Building fire
# 1                           NaN                          Building fire
# 2                           NaN                 Passenger vehicle fire
# 3                      Fineview                 Passenger vehicle fire
# 4                     Fairywood                          Building fire
# 5              South Side Flats            Outside rubbish fire, Other
# 6              Allegheny Center    Cooking fire, confined to container
# 7      Lincoln-Lemington-Belmar                          Building fire
# 8                       Carrick                          Building fire
# 9                     Beechview                 Passenger vehicle fire
# 10                    Allentown   Outside rubbish, trash or waste fire
# 11                  Beltzhoover       Trash or rubbish fire, contained
# 12                          NaN    Cooking fire, confined to container
# 13              Crafton Heights                          Building fire
# 14               Homewood North  Brush or brush-and-grass mixture fire
# 15          Squirrel Hill South            Special outside fire, Other
# 16                  Perry North                          Building fire
# 17                    Allentown   Outside rubbish, trash or waste fire
# 18                          NaN                 Passenger vehicle fire
# 19            Bedford Dwellings                          Building fire
# 20               Homewood South  Mobile property (vehicle) fire, Other
# 21               East Allegheny                          Building fire
# 22               Homewood North                          Building fire
# 23          Squirrel Hill South    Cooking fire, confined to container
# 24                  Beltzhoover                          Building fire
# 25             Crawford-Roberts                          Building fire
# 26                     Sheraden   Outside rubbish, trash or waste fire
# 27               Homewood South    Cooking fire, confined to container
# 28                  Middle Hill                          Building fire
# 29             South Side Flats            Outside rubbish fire, Other
# ...                         ...                                    ...
# 6607              South Oakland                 Passenger vehicle fire
# 6608          Central Northside    Cooking fire, confined to container
# 6609  Central Business District    Cooking fire, confined to container
# 6610                  Knoxville                          Building fire
# 6611                Perry North                          Building fire
# 6612                        NaN                 Passenger vehicle fire
# 6613                        NaN                          Building fire
# 6614                  Troy Hill                          Building fire
# 6615                  Shadyside    Cooking fire, confined to container
# 6616                Middle Hill            Special outside fire, Other
# 6617                        NaN                 Passenger vehicle fire
# 6618               East Liberty    Cooking fire, confined to container
# 6619                        NaN    Cooking fire, confined to container
# 6620                    Elliott                          Building fire
# 6621           Mount Washington                          Building fire
# 6622        Lower Lawrenceville  Brush or brush-and-grass mixture fire
# 6623   Lincoln-Lemington-Belmar    Cooking fire, confined to container
# 6624                        NaN    Cooking fire, confined to container
# 6625                  Shadyside            Special outside fire, Other
# 6626              North Oakland   Outside rubbish, trash or waste fire
# 6627                  Overbrook    Cooking fire, confined to container
# 6628             Strip District                          Building fire
# 6629                        NaN                          Building fire
# 6630              Highland Park                          Building fire
# 6631        Upper Lawrenceville    Cooking fire, confined to container
# 6632  Central Business District                          Building fire
# 6633                  Arlington                          Building fire
# 6634                    Carrick    Cooking fire, confined to container
# 6635        Squirrel Hill South    Cooking fire, confined to container
# 6636              Lincoln Place                          Building fire
#
# [6637 rows x 2 columns]

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
total_fires=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).value_counts()
print(total_fires)
# Out:
# neighborhood      type_description
# Allegheny Center  Cooking fire, confined to container                15
#                   Outside rubbish, trash or waste fire                6
#                   Dumpster or other outside trash receptacle fire     5
#                   Natural vegetation fire, Other                      5
#                   Brush or brush-and-grass mixture fire               3
#                   Building fire                                       2
#                   Special outside fire, Other                         2
#                   Trash or rubbish fire, contained                    2
#                   Fire in portable building, fixed location           1
#                   Fuel burner/boiler malfunction, fire confined       1
#                   Mobile property (vehicle) fire, Other               1
#                   Outside equipment fire                              1
#                   Outside rubbish fire, Other                         1
#                   Passenger vehicle fire                              1
# Allegheny West    Passenger vehicle fire                              8
#                   Building fire                                       5
#                   Dumpster or other outside trash receptacle fire     5
#                   Brush or brush-and-grass mixture fire               3
#                   Outside rubbish, trash or waste fire                3
#                   Commercial Compactor fire, confined to rubbish      2
#                   Natural vegetation fire, Other                      2
#                   Outside rubbish fire, Other                         2
#                   Cooking fire, confined to container                 1
#                   Grass fire                                          1
# Allentown         Building fire                                      34
#                   Cooking fire, confined to container                16
#                   Passenger vehicle fire                             10
#                   Outside rubbish, trash or waste fire                8
#                   Outside rubbish fire, Other                         6
#                   Dumpster or other outside trash receptacle fire     3
#                                                                      ..
# West Oakland      Commercial Compactor fire, confined to rubbish      2
#                   Dumpster or other outside trash receptacle fire     2
#                   Mobile property (vehicle) fire, Other               2
#                   Natural vegetation fire, Other                      2
#                   Outside rubbish, trash or waste fire                2
#                   Fire, Other                                         1
#                   Grass fire                                          1
# Westwood          Building fire                                       4
#                   Cooking fire, confined to container                 3
#                   Passenger vehicle fire                              3
#                   Brush or brush-and-grass mixture fire               2
#                   Dumpster or other outside trash receptacle fire     2
#                   Grass fire                                          2
#                   Fire, Other                                         1
#                   Natural vegetation fire, Other                      1
#                   Outside rubbish fire, Other                         1
#                   Outside rubbish, trash or waste fire                1
#                   Trash or rubbish fire, contained                    1
# Windgap           Brush or brush-and-grass mixture fire               2
#                   Building fire                                       2
#                   Cooking fire, confined to container                 2
#                   Outside rubbish fire, Other                         2
#                   Fire in mobile home used as fixed residence         1
#                   Forest, woods or wildland fire                      1
#                   Garbage dump or sanitary landfill fire              1
#                   Mobile property (vehicle) fire, Other               1
#                   Natural vegetation fire, Other                      1
#                   Outside rubbish, trash or waste fire                1
#                   Special outside fire, Other                         1
#                   Trash or rubbish fire, contained                    1
# Name: type_description, Length: 1158, dtype: int64

# %% [markdown]
# For this data table, we grouped each fire incident type reported with the corresponding neighborhood and summed up each fire incident type listed. I used the the .valuecounts() method to get the number of different fire incidents reported in a neighborhood. Now we need to organize the data so that it can be visualized.

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
print(pgh_fires_sum)
# Out:
# neighborhood
# Allegheny Center              46
# Allegheny West                32
# Allentown                     89
# Arlington                     40
# Arlington Heights              9
# Banksville                    49
# Bedford Dwellings             31
# Beechview                    103
# Beltzhoover                   97
# Bloomfield                   120
# Bluff                         88
# Bon Air                       16
# Brighton Heights             105
# Brookline                    127
# California-Kirkbride          31
# Carrick                      222
# Central Business District    189
# Central Lawrenceville         58
# Central Northside             96
# Central Oakland               69
# Chartiers City                11
# Chateau                       34
# Crafton Heights               66
# Crawford-Roberts              77
# Duquesne Heights              23
# East Allegheny                78
# East Carnegie                  6
# East Hills                   122
# East Liberty                 150
# Elliott                       47
#                             ...
# Perry North                   84
# Perry South                  128
# Point Breeze                  57
# Point Breeze North            35
# Polish Hill                   24
# Regent Square                  6
# Ridgemont                     12
# Shadyside                    129
# Sheraden                     135
# South Oakland                 68
# South Shore                   18
# South Side Flats             186
# South Side Slopes             71
# Spring Garden                 19
# Spring Hill-City View         80
# Squirrel Hill North           96
# Squirrel Hill South          180
# St. Clair                     11
# Stanton Heights               43
# Strip District                36
# Summer Hill                   16
# Swisshelm Park                11
# Terrace Village               70
# Troy Hill                     55
# Upper Hill                    34
# Upper Lawrenceville           36
# West End                      16
# West Oakland                  46
# Westwood                      21
# Windgap                       16
# Name: type_description, Length: 91, dtype: int64

# %% [markdown]
# We grouped the data by neighborhood and listed their respective fire incident total.

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
weight=pd.Series([5])
pgh_fires_sum.mul(weight, axis=0) 
print(pgh_fires_sum.sort_values(ascending=False))
# Out:
# neighborhood
# Carrick                      222
# Central Business District    189
# South Side Flats             186
# Hazelwood                    183
# Squirrel Hill South          180
# East Liberty                 150
# Lincoln-Lemington-Belmar     147
# Mount Washington             146
# Homewood North               146
# Sheraden                     135
# Shadyside                    129
# Perry South                  128
# Homewood South               128
# Brookline                    127
# East Hills                   122
# Bloomfield                   120
# Knoxville                    118
# Brighton Heights             105
# Beechview                    103
# Larimer                      102
# Marshall-Shadeland            97
# Beltzhoover                   97
# Squirrel Hill North           96
# Central Northside             96
# North Oakland                 93
# Allentown                     89
# Bluff                         88
# Perry North                   84
# Greenfield                    82
# Middle Hill                   80
#                             ...
# Chateau                       34
# Allegheny West                32
# Bedford Dwellings             31
# California-Kirkbride          31
# Morningside                   26
# Friendship                    25
# Polish Hill                   24
# Duquesne Heights              23
# Westwood                      21
# New Homestead                 20
# Spring Garden                 19
# Fairywood                     18
# South Shore                   18
# Glen Hazel                    17
# West End                      16
# Summer Hill                   16
# Bon Air                       16
# Windgap                       16
# Esplen                        15
# Ridgemont                     12
# St. Clair                     11
# Swisshelm Park                11
# Chartiers City                11
# Hays                          11
# Oakwood                       10
# Arlington Heights              9
# Mt. Oliver                     7
# East Carnegie                  6
# Regent Square                  6
# Mount Oliver Borough           4
# Name: type_description, Length: 91, dtype: int64

# %% [markdown]
# Finally we listed the data in order of highest fire incidents reported to lowest. The dataset reveals that Carrick had the highest with 221 and Mount Oliver Borough had the lowest fire incidents reported with only 4.

# %%
import matplotlib.pyplot as plt
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count()
plt.ylabel('Number of fire incidents')
print(pgh_fires_sum.plot.bar(figsize=(25,2), width=0.5, position=1, fontsize=14))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# Finally we're able to neatly visualize the data with a bar graph displaying the different number of fire incidents reported in each Pittsburgh neighborhood.

# %% [markdown]
# # Test Number 3: Police Arrests

# %%
import pandas as pd
pgh_police=pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
pgh_police.head(10)
# Out:
#         PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# 5  1974556  16144301  45.0      M    W  2016-08-15T13:30:00
# 6  1974628  16147655  29.0      M    W  2016-08-16T13:00:00
# 7  1974607  16146037  21.0      F    B  2016-08-16T04:25:00
# 8  1974643  16132537  17.0      M    B  2016-08-29T17:55:00
# 9  1974647  16138646  14.0      M    B  2016-08-23T13:36:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4         900 Block Woodlow ST Pittsburgh, PA 15205
# 5             600 Block 1st AV Pittsburgh, PA 15219
# 6        2300 Block Pioneer AV Pittsburgh, PA 15226
# 7             600 Block 1st AV Pittsburgh, PA 15219
# 8     1400 Block Washington BL Pittsburgh, PA 15206
# 9                                            Zone 2
#
#                                             OFFENSES  \
# 0                                 3929 Retail Theft.
# 1       13(a)(16) Possession of Controlled Substance
# 2                                 3929 Retail Theft.
# 3  5503 Disorderly Conduct. / 5505 Public Drunken...
# 4  2702 Aggravated Assault. / 2705 Recklessy Enda...
# 5                                 3929 Retail Theft.
# 6                               2701 Simple Assault.
# 7  2701 Simple Assault. / 5505 Public Drunkenness...
# 8           903 Criminal Conspiracy. / 3701 Robbery.
# 9  3127 Indecent Exposure. / 3123(a)(6) IDSI with...
#
#                                    INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213           Bloomfield
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205         Outside City
# 2        900 Block Freeport RD Fox Chapel, PA 15238             Westwood
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212       East Allegheny
# 4         900 Block Woodlow ST Pittsburgh, PA 15205      Crafton Heights
# 5       800 Block Hazelwood AV Pittsburgh, PA 15217           Greenfield
# 6        2300 Block Pioneer AV Pittsburgh, PA 15226            Brookline
# 7      700 Block S Braddock AV Pittsburgh, PA 15221        Regent Square
# 8       N Euclid AV & Broad ST Pittsburgh, PA 15206         East Liberty
# 9                                            Zone 5                  NaN
#
#   INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 0            5          804.0               8.0                    2.0
# 1          OSC         5599.0               NaN                    NaN
# 2            5         2811.0               9.0                    2.0
# 3            1         2304.0               1.0                    1.0
# 4            5         2814.0               2.0                    5.0
# 5            4         1517.0               5.0                    3.0
# 6            6         1919.0               4.0                    5.0
# 7            4         1410.0               NaN                    NaN
# 8            5         1115.0               NaN                    NaN
# 9            5            NaN               NaN                    NaN
#
#            X          Y
# 0 -79.949277  40.452551
# 1 -80.088018  40.440136
# 2 -79.891803  40.486625
# 3 -80.001939  40.454080
# 4 -80.052204  40.445900
# 5 -79.929238  40.419699
# 6 -80.020357  40.400037
# 7 -79.834462  40.398957
# 8   0.000000   0.000000
# 9        NaN        NaN

# %%
import pandas as pd
pgh_police=pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
pgh_police_sum=pgh_police['OFFENSES'].groupby(pgh_police['INCIDENTNEIGHBORHOOD']).count()
print(pgh_police_sum)
# Out:
# INCIDENTNEIGHBORHOOD
# Allegheny Center              674
# Allegheny West                 76
# Allentown                     553
# Arlington                     171
# Arlington Heights             101
# Banksville                    142
# Bedford Dwellings             344
# Beechview                     714
# Beltzhoover                   319
# Bloomfield                    568
# Bluff                         802
# Bon Air                       130
# Brighton Heights              623
# Brookline                     710
# California-Kirkbride          156
# Carrick                      1361
# Central Business District    2177
# Central Lawrenceville         277
# Central North Side            498
# Central Northside              23
# Central Oakland               309
# Chartiers City                 23
# Chateau                       271
# Crafton Heights               300
# Crawford-Roberts              474
# Duquesne Heights              103
# East Allegheny               1270
# East Carnegie                  29
# East Hills                    588
# East Liberty                 1013
#                              ...
# Perry South                   648
# Point Breeze                  185
# Point Breeze North            135
# Polish Hill                    99
# Regent Square                  19
# Ridgemont                      15
# Shadyside                     551
# Sheraden                      666
# South Oakland                 176
# South Shore                   160
# South Side Flats             1970
# South Side Slopes             466
# Spring Garden                 154
# Spring Hill-City View         435
# Squirrel Hill North           159
# Squirrel Hill South           451
# St. Clair                      32
# Stanton Heights               119
# Strip District                278
# Summer Hill                    46
# Swisshelm Park                 20
# Terrace Village               142
# Troy Hill                     261
# Troy Hill-Herrs Island          6
# Upper Hill                    220
# Upper Lawrenceville           115
# West End                      158
# West Oakland                  182
# Westwood                      120
# Windgap                        60
# Name: OFFENSES, Length: 98, dtype: int64

# %%
import pandas as pd
pgh_police=pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
pgh_police_sum=pgh_police['OFFENSES'].groupby(pgh_police['INCIDENTNEIGHBORHOOD']).count()
print(pgh_police_sum.sort_values(ascending=False))
# Out:
# INCIDENTNEIGHBORHOOD
# Central Business District      2177
# South Side Flats               1970
# Carrick                        1361
# East Allegheny                 1270
# Homewood South                 1167
# Homewood North                 1054
# East Liberty                   1013
# Marshall-Shadeland              868
# Mount Washington                853
# Bluff                           802
# Knoxville                       770
# Hazelwood                       718
# Beechview                       714
# Brookline                       710
# Lincoln-Lemington-Belmar        703
# Allegheny Center                674
# Sheraden                        666
# Perry South                     648
# Brighton Heights                623
# East Hills                      588
# Middle Hill                     577
# Bloomfield                      568
# Allentown                       553
# Shadyside                       551
# Fineview                        503
# Central North Side              498
# North Shore                     480
# Crawford-Roberts                474
# South Side Slopes               466
# Larimer                         460
#                                ...
# Upper Lawrenceville             115
# Morningside                     113
# Friendship                      111
# Esplen                          107
# Lincoln Place                   103
# Duquesne Heights                103
# Arlington Heights               101
# Polish Hill                      99
# Mount Oliver                     90
# Golden Triangle/Civic Arena      83
# Allegheny West                   76
# Glen Hazel                       70
# Fairywood                        63
# Hays                             62
# Windgap                          60
# Summer Hill                      46
# Oakwood                          45
# Outside State                    39
# Outside County                   36
# St. Clair                        32
# East Carnegie                    29
# Central Northside                23
# Chartiers City                   23
# New Homestead                    23
# Swisshelm Park                   20
# Regent Square                    19
# Ridgemont                        15
# Mt. Oliver Boro                  12
# Troy Hill-Herrs Island            6
# Mt. Oliver Neighborhood           2
# Name: OFFENSES, Length: 98, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
pgh_police=pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
pgh_police_sum=pgh_police['OFFENSES'].groupby(pgh_police['INCIDENTNEIGHBORHOOD']).count()
plt.ylabel('Number of police arrests')
print(pgh_police_sum.plot.bar(figsize=(25,2), width=0.5, position=1, fontsize=14))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # *The Best Neighborhood*
# To determine which neighborhood is truly the best, we added weights to the fire and police arrest data by mutiplying the fire incident dataset (pgh_fires) by five and dividing the police arrests (pgh_police) by two. This allowed us to compensate for the newer datasets with less datapoints than the others. The Best neighborhood ended up being East Carnegie with 62.5 points. Although East Carnegie didn't have the lowest number of points it did have the lowest number of points out of any neighborhood in all three datasets. This means that East Carnegie is one of if not the safest neighborhood in Pittsburgh. The worst neighborhood in Pittsburgh according to these datasets is Squirrel Hill South with 2191.5 points. As the only neighborhood in all three datasets with a score this high with top ten apperances in fires and reports Squirrel Hill has earned the title of "least safe neighborhood in Pittsburgh". However, surprisingly while only being in two datsets the Central Business District is in a close second with 2033 points. While we only counted the neighborhoods in all three datasets because we were looking for the best neighborhood and having missing data would be a huge advantage in that category, it's clear to see the Central Business District is the actual worst neighborhood in Pittsburgh.

# %%
import pandas as pd
pgh_police=pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
pgh_police_sum=pgh_police['OFFENSES'].groupby(pgh_police['INCIDENTNEIGHBORHOOD']).count().apply(lambda x: x*0.5).sort_values(ascending=False)
print(pgh_police_sum.head(40))
print(pgh_police_sum.tail(30))
# Out:
# INCIDENTNEIGHBORHOOD
# Central Business District    1088.5
# South Side Flats              985.0
# Carrick                       680.5
# East Allegheny                635.0
# Homewood South                583.5
# Homewood North                527.0
# East Liberty                  506.5
# Marshall-Shadeland            434.0
# Mount Washington              426.5
# Bluff                         401.0
# Knoxville                     385.0
# Hazelwood                     359.0
# Beechview                     357.0
# Brookline                     355.0
# Lincoln-Lemington-Belmar      351.5
# Allegheny Center              337.0
# Sheraden                      333.0
# Perry South                   324.0
# Brighton Heights              311.5
# East Hills                    294.0
# Middle Hill                   288.5
# Bloomfield                    284.0
# Allentown                     276.5
# Shadyside                     275.5
# Fineview                      251.5
# Central North Side            249.0
# North Shore                   240.0
# Crawford-Roberts              237.0
# South Side Slopes             233.0
# Larimer                       230.0
# Squirrel Hill South           225.5
# Spring Hill-City View         217.5
# Homewood West                 214.0
# Perry North                   205.5
# Garfield                      199.5
# Northview Heights             194.0
# Elliott                       178.5
# Bedford Dwellings             172.0
# Beltzhoover                   159.5
# Central Oakland               154.5
# Name: OFFENSES, dtype: float64
# INCIDENTNEIGHBORHOOD
# Upper Lawrenceville            57.5
# Morningside                    56.5
# Friendship                     55.5
# Esplen                         53.5
# Lincoln Place                  51.5
# Duquesne Heights               51.5
# Arlington Heights              50.5
# Polish Hill                    49.5
# Mount Oliver                   45.0
# Golden Triangle/Civic Arena    41.5
# Allegheny West                 38.0
# Glen Hazel                     35.0
# Fairywood                      31.5
# Hays                           31.0
# Windgap                        30.0
# Summer Hill                    23.0
# Oakwood                        22.5
# Outside State                  19.5
# Outside County                 18.0
# St. Clair                      16.0
# East Carnegie                  14.5
# Central Northside              11.5
# Chartiers City                 11.5
# New Homestead                  11.5
# Swisshelm Park                 10.0
# Regent Square                   9.5
# Ridgemont                       7.5
# Mt. Oliver Boro                 6.0
# Troy Hill-Herrs Island          3.0
# Mt. Oliver Neighborhood         1.0
# Name: OFFENSES, dtype: float64

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count().apply(lambda x: x*5).sort_values(ascending=False)
print(pgh_fires_sum)
# Out:
# neighborhood
# Carrick                      1110
# Central Business District     945
# South Side Flats              930
# Hazelwood                     915
# Squirrel Hill South           900
# East Liberty                  750
# Lincoln-Lemington-Belmar      735
# Mount Washington              730
# Homewood North                730
# Sheraden                      675
# Shadyside                     645
# Perry South                   640
# Homewood South                640
# Brookline                     635
# East Hills                    610
# Bloomfield                    600
# Knoxville                     590
# Brighton Heights              525
# Beechview                     515
# Larimer                       510
# Marshall-Shadeland            485
# Beltzhoover                   485
# Squirrel Hill North           480
# Central Northside             480
# North Oakland                 465
# Allentown                     445
# Bluff                         440
# Perry North                   420
# Greenfield                    410
# Middle Hill                   400
#                              ...
# Chateau                       170
# Allegheny West                160
# Bedford Dwellings             155
# California-Kirkbride          155
# Morningside                   130
# Friendship                    125
# Polish Hill                   120
# Duquesne Heights              115
# Westwood                      105
# New Homestead                 100
# Spring Garden                  95
# Fairywood                      90
# South Shore                    90
# Glen Hazel                     85
# West End                       80
# Summer Hill                    80
# Bon Air                        80
# Windgap                        80
# Esplen                         75
# Ridgemont                      60
# St. Clair                      55
# Swisshelm Park                 55
# Chartiers City                 55
# Hays                           55
# Oakwood                        50
# Arlington Heights              45
# Mt. Oliver                     35
# East Carnegie                  30
# Regent Square                  30
# Mount Oliver Borough           20
# Name: type_description, Length: 91, dtype: int64

# %%
import pandas as pd
pgh_police=pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
pgh_police_sum=pgh_police['OFFENSES'].groupby(pgh_police['INCIDENTNEIGHBORHOOD']).count().apply(lambda x: x*0.5).sort_values(ascending=False)
plt.ylabel('Number of police arrests')
print(pgh_police_sum.plot.bar(figsize=(25,2), width=0.5, position=1, fontsize=14))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import pandas as pd
pgh_fires=pd.read_csv("https://data.wprdc.org/datastore/dump/8d76ac6b-5ae8-4428-82a4-043130d17b02")
pgh_fires_sum=pgh_fires['type_description'].groupby(pgh_fires['neighborhood']).count().apply(lambda x: x*5).sort_values(ascending=False)
plt.ylabel('Number of fire incidents')
print(pgh_fires_sum.plot.bar(figsize=(25,2), width=0.5, position=1, fontsize=14))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
neighborhoods=pgh_arrests['neighborhood']
pgh_arrests['sum_of_arrests']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
pgh_arrests_total=pgh_arrests[['neighborhood','sum_of_arrests']].plot.bar(figsize=(25,2),width=0.5, position=1)
plt.xticks(pgh_arrests.index,pgh_arrests['neighborhood'].values, fontsize=14)
plt.ylabel('Number of Incident Reports')
print(pgh_arrests_total)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import pandas as pd
pgh_arrests=pd.read_csv("https://data.wprdc.org/dataset/bce15079-618a-4bf3-badf-8aa372c3aea2/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75/download/arrests-for-major-crimes-1972.csv")
pgh_arrests['sum_of_reports']=pgh_arrests['number_arrests_murder']+pgh_arrests['number_arrests_larceny']+pgh_arrests['number_arrests_rape']+ pgh_arrests['number_arrests_robbery']+pgh_arrests['number_arrests_assault']+pgh_arrests['number_arrests_burglary']
amount=pgh_arrests[['neighborhood','sum_of_reports']].sort_values(by='sum_of_reports', ascending=False)
print(amount.head(10))
print(amount.tail(10))
# Out:
#                            neighborhood  sum_of_reports
# 52                            Shadyside            1229
# 59      Squirrel Hill - South of Forbes            1066
# 43                        North Oakland             926
# 58      Squirrel Hill - North of Forbes             816
# 16                   Central North Side             728
# 40                          Middle Hill             710
# 20                         East Liberty             674
# 38                        Lower Oakland             645
# 42  Mount Washington - Duquesne Heights             602
# 31                       Homewood South             595
#        neighborhood  sum_of_reports
# 22           Elliot              84
# 41      Morningside              76
# 14  California Ave.              58
# 49    Regent Square              55
# 69  West End Valley              46
# 23           Esplen              43
# 11          Bon Air              42
# 63   Swisshelm Park              35
# 27   Harpen Hilltop              23
# 18    East Carnegie              18

# %% [markdown]
# Janet's Conclusion: I do not have much experience with the city of Pittsburgh neighborhoods, but when East Carnegie came out as the winner I was not surprised because on websites such as Niche it comes up as one of the safest neighborhoods. I thought Downtown Pittsburgh should also be shown in our d    ata as the best, but our datafiles did not include this neighborhood in their studies.

# %% [markdown]
# Simon's Conclusion: After comparing multiple factors, we determined that East Carnegie was the Best neighborhood due to its low rates of crime fires and incidents. Being from Philadelphia I had no idea which neighborhoods would come out on top. However, after comparing almost every neighborhood in Pittsburgh East Carnegie was found in the top ten lowest fires, crime and incidents. No other neighborhood did that. The metric of city services needed, meaning police or firefighters was catered to one of the top concerns for home buyers, safety. The worst neighborhood we analyzed was Squirrel Hill South. Although it never took the number one spot in any of the categories Squirrel Hill South was in both top ten fire incidents and incident reports. Being one of the only neighborhoods with over one thousand crime incident reports and over one hundred fire incidents. Initially when I saw Shadyside’s crime incident reports with over two-hundred more incidents than the second worst neighborhood I thought that it was going to be the worst neighborhood. However, having been to Shadyside I know that it’s a really nice place. This is because the dataset included reports which may happen more often than actual incidents. It is possible that because it’s a nicer neighborhood the community is more vigilant about reporting things. If I were to change anything about the way we did this project, I would choose more diverse metrics. We choose to have a focus on safety which is a top concern for most people when choosing where to live but more diverse data sets would give a better picture of the overall best neighborhood rather than just the safest.
